# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
df_train = pd.read_csv("./data_train_pso.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)
df_train
# Out:
#       label     2           5         7         8           9    11    12  \
# 0       0.0  10.0  274.986868 -0.319753 -1.432466  325.821586  84.0   9.0
# 1       0.0  17.0  104.913059  0.158313 -0.696295  336.569414  32.0  10.0
# 2       3.0  16.0    4.687572  0.396421 -0.312612   94.909877  -2.0  16.0
# 3       3.0  23.0    3.591772 -0.021014 -0.856142  254.059787   9.0  10.0
# 4       1.0   9.0   25.118469 -0.276816 -1.271399  461.130814  -1.0   9.0
# ...     ...   ...         ...       ...       ...         ...   ...   ...
# 8511    3.0  16.0   51.114860  2.153820  2.645687  365.256750  -2.0  15.0
# 8512    1.0   9.0    5.894913 -0.311206 -1.184514  358.414529  -5.0   9.0
# 8513    2.0  15.0  107.653355  0.475616  0.784000  180.045117  20.0  14.0
# 8514    1.0   9.0   24.535688 -0.263431 -1.567800  251.455499  -1.0   9.0
# 8515    1.0   9.0    8.242421  0.214800 -1.575835  505.203302  -2.0   9.0
#
#         13          14  ...           181         186       187        193  \
# 0      9.0  437.750000  ...   2383.209877  650.000000 -0.338865   9.000000
# 1     16.0  312.222222  ...   2193.439446  384.000000  0.095966   3.000000
# 2     15.0  329.600000  ...     49.109375   14.000000  0.217133  15.000000
# 3      0.0    0.036070  ...      0.045933   14.000000 -0.026782   6.000000
# 4      8.0  427.250000  ...    736.000000   72.000000 -0.285584   8.000000
# ...    ...         ...  ...           ...         ...       ...        ...
# 8511  15.0  342.666667  ...  22201.000000    0.003006  0.003006   0.003006
# 8512   8.0  481.250000  ...   2913.580247   24.000000 -0.625647   8.000000
# 8513  14.0  341.714286  ...   2954.775510  136.000000  0.385381  12.000000
# 8514   8.0  449.750000  ...     24.000000   64.000000 -0.320207   7.000000
# 8515   8.0  463.500000  ...     11.358025   22.000000  0.218367   7.000000
#
#               197          203       204         205           209         212
# 0      950.222222   991.309467  1.000000  172.000000  10656.395062  135.800000
# 1      574.500000   912.932251  0.882353  -15.000000   3944.000000   -1.066667
# 2      593.733333   338.632833  1.000000   -4.000000   2058.773333   95.500000
# 3      420.181818   325.369999  0.739130   -9.000000   1120.888889   12.000000
# 4     1068.750000   877.512514  1.000000    2.000000    671.000000  136.444444
# ...           ...          ...       ...         ...           ...         ...
# 8511     0.003757     0.003757  0.003757    0.022262      0.044242    0.037385
# 8512  1091.750000   267.711052  0.888889   -3.000000   1294.530612  155.333333
# 8513   654.571429   484.863590  1.000000   -4.000000   2213.551020  104.000000
# 8514  1075.000000   704.569046  1.000000   14.000000   4933.551020   88.222222
# 8515  1041.000000  1946.010560  1.000000    0.000000    350.000000  150.000000
#
# [8516 rows x 99 columns]

# %%
df_test = pd.read_csv("./data_test_pso.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)
df_test
# Out:
#         0     1           4         6          7           8    10    11  \
# 0     0.0  14.0  153.204817  0.996355   0.207174  459.037295 -28.0  13.0
# 1     0.0  10.0  266.399867  0.979352   0.388359  398.464564 -60.0  10.0
# 2     0.0  11.0  251.329664  0.260470  -1.002325  340.802438 -52.0   8.0
# 3     2.0  13.0    8.986100  0.048579  -1.449012  412.324324  -5.0  12.0
# 4     0.0  23.0   82.344017  3.023659  10.404884  168.041577   7.0   9.0
# ...   ...   ...         ...       ...        ...         ...   ...   ...
# 2125  1.0   9.0   36.509417  1.263183   0.543003  364.303573 -18.0   9.0
# 2126  1.0   8.0   33.839959 -0.454057  -1.036905  181.876516   0.0   8.0
# 2127  3.0  16.0   23.734082  0.371174  -0.657132  137.696567 -10.0  16.0
# 2128  1.0   8.0  180.470587  0.587475  -1.363827  561.988537  12.0   8.0
# 2129  3.0  25.0    2.569857  0.605786  -0.869886  654.123072  46.0   0.0
#
#         12          13  ...          180    185       186   192          196  \
# 0     13.0  358.307692  ...    92.686391  554.0  0.999941  10.0   710.615385
# 1      6.0  532.800000  ...  7281.937500  932.0  0.965488   4.0   968.222222
# 2      7.0  403.000000  ...  2661.728395  784.0  0.270281   6.0   796.400000
# 3     12.0  322.333333  ...   787.638889   26.0 -0.014314  12.0   757.333333
# 4     20.0  223.750000  ...  1288.640000  398.0  1.761865  16.0   396.173913
# ...    ...         ...  ...          ...    ...       ...   ...          ...
# 2125   8.0  438.571429  ...  4051.918367  118.0  1.263183   8.0  1071.250000
# 2126   7.0  463.142857  ...    10.750000  104.0 -0.457057   5.0  1196.000000
# 2127  15.0  335.733333  ...   739.982222   82.0  0.348673  14.0   595.600000
# 2128   7.0  462.000000  ...   431.750000  448.0  0.587475   5.0  1080.571429
# 2129   5.0    0.036070  ...     0.045933   10.0  0.989051   0.0   391.250000
#
#               202       203        204           208         211
# 0      794.307350  0.928571 -10.000000    729.000000  127.600000
# 1      900.143486  0.600000  64.000000  15314.750000  112.285714
# 2     1236.308241  1.000000  26.000000   1944.489796  131.111111
# 3      803.828940  1.000000  -4.000000   6122.750000  121.833333
# 4      316.582423  0.083333   0.022262      0.044242   45.818182
# ...           ...       ...        ...           ...         ...
# 2125   856.643246  0.777778   0.000000   2843.265306   96.000000
# 2126   746.905354  1.000000 -26.000000    228.555556  169.142857
# 2127   333.718093  1.000000  -8.000000   1270.061224   90.400000
# 2128   588.205240  1.000000  18.000000     51.840000  101.000000
# 2129  1293.658260  0.240000   4.000000      0.044242    0.037385
#
# [2130 rows x 99 columns]

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
scale = MinMaxScaler()
x_train = scale.fit_transform(x_train)
x_test = scale.fit_transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train , test_size=0.5, shuffle=True, stratify=y_train, random_state=119)
print(f"Train: {x_train.shape}")
print(f"Vallidation: {x_val.shape}")
# Out:
# Train: (4258, 98)
# Vallidation: (4258, 98)

# %%
rf_clf = RandomForestClassifier(criterion= 'log_loss', max_depth= 5, max_features= 'sqrt', n_estimators= 1000)
ab_clf = AdaBoostClassifier(algorithm= 'SAMME.R', learning_rate= 0.1, n_estimators= 50)
knn_clf = KNeighborsClassifier(algorithm= 'auto', n_neighbors= 5, p= 1, weights= 'uniform')
svc_clf = SVC(C= 100, gamma= 'scale', kernel= 'rbf', probability= True)
xgb_clf = XGBClassifier(gamma= 0,learning_rate= 0.1,max_depth= 5,min_child_weight= 1,n_estimators= 1000)
dt_clf = DecisionTreeClassifier(criterion= 'entropy',max_depth= 5,max_features= 'sqrt',splitter= 'best')
lgb_clf = LGBMClassifier(boosting = 'gbdt', data_sample_strategy= 'goss', estimators=50, learning_rate = 0.1, objective= 'multiclass')
cb_clf = CatBoostClassifier(iterations = 10, learning_rate= 0.1)
gb_clf = GradientBoostingClassifier(criterion='squared_error', learning_rate = 0.1, loss= 'log_loss', n_estimators=200)

# %%
# Huấn luyện các mô hình con
rf_clf.fit(x_train,y_train)
ab_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
svc_clf.fit(x_train, y_train)
xgb_clf.fit(x_train, y_train)
dt_clf.fit(x_train,y_train)
# lgb_clf.fit(x_train, y_train)
# cb_clf.fit(x_train, y_train)
# gb_clf.fit(x_train, y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt')

# %%
# Dự đoán trên tập huấn luyện để tạo đặc trưng mới cho mô hình blending
X_train_meta = np.column_stack((
    rf_clf.predict_proba(x_val),
    ab_clf.predict_proba(x_val),
    knn_clf.predict_proba(x_val),
    svc_clf.predict_proba(x_val),
    xgb_clf.predict_proba(x_val),
    dt_clf.predict_proba(x_val),
    # lgb_clf.predict_proba(x_val),
    # cb_clf.predict_proba(x_val)
    # gb_clf.predict_proba(x_val)
))
# Dự đoán trên tập kiểm tra để tạo đặc trưng mới cho mô hình blending
X_test_meta = np.column_stack((
    rf_clf.predict_proba(x_test),
    ab_clf.predict_proba(x_test),
    knn_clf.predict_proba(x_test),
    svc_clf.predict_proba(x_test),
    xgb_clf.predict_proba(x_test),
    dt_clf.predict_proba(x_test),
    # lgb_clf.predict_proba(x_test),
    # cb_clf.predict_proba(x_test)
    # gb_clf.predict_proba(x_test)
))

# %%
print(f"X_train_meta:{X_train_meta.shape}")
print(f"X_test_meta:{X_test_meta.shape}")
# Out:
# X_train_meta:(4258, 24)
# X_test_meta:(2130, 24)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
model = GradientBoostingClassifier()
params = {
    'loss':['log_loss', 'deviance', 'exponential'],
    'learning_rate':[0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1],
    'n_estimators':[50, 75, 100],
    'criterion':['friedman_mse', 'squared_error']
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X_train_meta,y_val)
# Out:
# Fitting 3 folds for each of 126 candidates, totalling 378 fits
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.365, test=0.365) total time=   2.7s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.366, test=0.365) total time=   2.6s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.365, test=0.366) total time=   2.6s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.365, test=0.365) total time=   4.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.366, test=0.365) total time=   3.9s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.365, test=0.366) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.365, test=0.365) total time=   5.2s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.366, test=0.365) total time=   5.2s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.365, test=0.366) total time=   5.3s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.882, test=0.878) total time=   2.6s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.893, test=0.885) total time=   2.6s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.908, test=0.891) total time=   2.6s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.955, test=0.949) total time=   3.9s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.957, test=0.953) total time=   3.9s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.955, test=0.934) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.963, test=0.956) total time=   5.1s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.961, test=0.952) total time=   5.2s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.966, test=0.949) total time=   5.2s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.963, test=0.956) total time=   2.5s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.961, test=0.953) total time=   2.6s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.966, test=0.949) total time=   2.5s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.967, test=0.960) total time=   3.8s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.965, test=0.957) total time=   3.9s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.969, test=0.949) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.967, test=0.959) total time=   5.2s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.966, test=0.956) total time=   5.1s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.969, test=0.949) total time=   5.2s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.967, test=0.959) total time=   2.5s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.966, test=0.957) total time=   2.6s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.969, test=0.949) total time=   2.5s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.965, test=0.958) total time=   3.8s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.967, test=0.958) total time=   3.8s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.969, test=0.949) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.965, test=0.958) total time=   5.1s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.968, test=0.958) total time=   5.2s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.970, test=0.949) total time=   5.2s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.969, test=0.958) total time=   2.5s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.970, test=0.958) total time=   2.5s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.971, test=0.948) total time=   2.5s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.972, test=0.957) total time=   3.8s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.971, test=0.958) total time=   3.8s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.976, test=0.947) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.973, test=0.957) total time=   5.2s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.974, test=0.957) total time=   5.1s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.980, test=0.948) total time=   5.1s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.974, test=0.957) total time=   2.5s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.974, test=0.958) total time=   2.5s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.980, test=0.948) total time=   2.5s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.980, test=0.956) total time=   3.9s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.980, test=0.959) total time=   3.8s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.986, test=0.947) total time=   3.9s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.990, test=0.956) total time=   5.2s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.984, test=0.958) total time=   5.5s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.991, test=0.946) total time=   5.4s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.983, test=0.956) total time=   2.6s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.982, test=0.956) total time=   2.6s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.989, test=0.949) total time=   2.7s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.993, test=0.956) total time=   4.4s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.991, test=0.956) total time=   4.3s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.999, test=0.947) total time=   4.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.997, test=0.957) total time=   5.2s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.996, test=0.956) total time=   5.5s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.999, test=0.946) total time=   5.5s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=friedman_mse, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.365, test=0.365) total time=   2.7s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.366, test=0.365) total time=   2.8s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=50;, score=(train=0.365, test=0.366) total time=   2.8s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.365, test=0.365) total time=   4.2s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.366, test=0.365) total time=   4.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=75;, score=(train=0.365, test=0.366) total time=   3.9s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.365, test=0.365) total time=   5.7s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.366, test=0.365) total time=   5.6s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=log_loss, n_estimators=100;, score=(train=0.365, test=0.366) total time=   5.7s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.001, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.882, test=0.878) total time=   2.8s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.893, test=0.885) total time=   2.9s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=50;, score=(train=0.908, test=0.891) total time=   2.8s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.955, test=0.949) total time=   3.8s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.957, test=0.953) total time=   3.7s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=75;, score=(train=0.955, test=0.933) total time=   3.9s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.963, test=0.956) total time=   5.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.961, test=0.952) total time=   5.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=log_loss, n_estimators=100;, score=(train=0.966, test=0.949) total time=   5.3s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.003, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.963, test=0.956) total time=   2.6s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.961, test=0.953) total time=   2.7s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=50;, score=(train=0.966, test=0.949) total time=   2.7s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.967, test=0.960) total time=   3.9s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.965, test=0.957) total time=   4.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=75;, score=(train=0.969, test=0.949) total time=   3.9s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.967, test=0.959) total time=   5.1s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.966, test=0.956) total time=   5.1s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=log_loss, n_estimators=100;, score=(train=0.969, test=0.949) total time=   5.2s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.006, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.967, test=0.959) total time=   2.5s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.966, test=0.957) total time=   2.5s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=50;, score=(train=0.969, test=0.949) total time=   2.5s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.965, test=0.958) total time=   3.9s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.967, test=0.958) total time=   4.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=75;, score=(train=0.969, test=0.949) total time=   4.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.965, test=0.958) total time=   5.4s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.968, test=0.958) total time=   5.3s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=log_loss, n_estimators=100;, score=(train=0.970, test=0.949) total time=   5.2s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.01, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.969, test=0.958) total time=   2.6s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.970, test=0.958) total time=   2.5s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=50;, score=(train=0.971, test=0.948) total time=   2.6s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.972, test=0.957) total time=   3.9s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.971, test=0.958) total time=   3.8s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=75;, score=(train=0.975, test=0.947) total time=   3.9s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.973, test=0.957) total time=   5.2s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.974, test=0.957) total time=   5.2s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=log_loss, n_estimators=100;, score=(train=0.980, test=0.947) total time=   5.1s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.03, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.974, test=0.957) total time=   2.5s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.974, test=0.958) total time=   2.6s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=50;, score=(train=0.980, test=0.946) total time=   2.5s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.980, test=0.956) total time=   3.8s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.980, test=0.960) total time=   3.8s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=75;, score=(train=0.986, test=0.946) total time=   3.9s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.990, test=0.956) total time=   5.1s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.984, test=0.958) total time=   5.2s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=log_loss, n_estimators=100;, score=(train=0.991, test=0.946) total time=   5.2s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.06, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.983, test=0.956) total time=   2.5s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.982, test=0.956) total time=   2.5s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=50;, score=(train=0.989, test=0.949) total time=   2.5s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.993, test=0.956) total time=   3.8s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.990, test=0.956) total time=   3.9s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=75;, score=(train=0.997, test=0.946) total time=   4.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.997, test=0.958) total time=   5.4s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.996, test=0.957) total time=   5.3s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=log_loss, n_estimators=100;, score=(train=0.999, test=0.946) total time=   5.3s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=deviance, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=50;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=75;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=squared_error, learning_rate=0.1, loss=exponential, n_estimators=100;, score=(train=nan, test=nan) total time=   0.0s
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:542: FitFailedWarning:
# 252 fits failed out of a total of 378.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1344, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'loss' parameter of GradientBoostingClassifier must be a str among {'log_loss', 'exponential'}. Got 'deviance' instead.
#
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1351, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_gb.py", line 673, in fit
#     self._loss = self._get_loss(sample_weight=sample_weight)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_gb.py", line 1537, in _get_loss
#     raise ValueError(
# ValueError: loss='exponential' is only suitable for a binary classification problem, you have n_classes=4. Please use loss='log_loss' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.36542976 0.36542976 0.36542976        nan        nan        nan
#         nan        nan        nan 0.88492409 0.94504379 0.95232426
#         nan        nan        nan        nan        nan        nan
#  0.95279407 0.95537706 0.9546725         nan        nan        nan
#         nan        nan        nan 0.95514232 0.95514248 0.95514265
#         nan        nan        nan        nan        nan        nan
#  0.95467283 0.95396828 0.95396828        nan        nan        nan
#         nan        nan        nan 0.95420318 0.95420335 0.95302898
#         nan        nan        nan        nan        nan        nan
#  0.95373354 0.95302881 0.95302865        nan        nan        nan
#         nan        nan        nan 0.36542976 0.36542976 0.36542976
#         nan        nan        nan        nan        nan        nan
#  0.88492409 0.94480888 0.95232426        nan        nan        nan
#         nan        nan        nan 0.95279407 0.95537706 0.9546725
#         nan        nan        nan        nan        nan        nan
#  0.95514232 0.95514248 0.95537739        nan        nan        nan
#         nan        nan        nan 0.95467283 0.95396828 0.95373337
#         nan        nan        nan        nan        nan        nan
#  0.95373337 0.95420335 0.95349863        nan        nan        nan
#         nan        nan        nan 0.95373354 0.952559   0.9534983
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the train scores are non-finite: [0.36542978 0.36542978 0.36542978        nan        nan        nan
#         nan        nan        nan 0.89443258 0.95537801 0.96336308
#         nan        nan        nan        nan        nan        nan
#  0.96336308 0.96688582 0.9672381         nan        nan        nan
#         nan        nan        nan 0.96712069 0.96712052 0.96759017
#         nan        nan        nan        nan        nan        nan
#  0.97017369 0.97299192 0.97534025        nan        nan        nan
#         nan        nan        nan 0.97580998 0.98215098 0.98825762
#         nan        nan        nan        nan        nan        nan
#  0.98473447 0.99424601 0.99753401        nan        nan        nan
#         nan        nan        nan 0.36542978 0.36542978 0.36542978
#         nan        nan        nan        nan        nan        nan
#  0.89443258 0.95537801 0.96336308        nan        nan        nan
#         nan        nan        nan 0.96336308 0.96688582 0.9672381
#         nan        nan        nan        nan        nan        nan
#  0.96712069 0.96712052 0.96759017        nan        nan        nan
#         nan        nan        nan 0.97017369 0.97275709 0.97534025
#         nan        nan        nan        nan        nan        nan
#  0.97580998 0.98203357 0.98825762        nan        nan        nan
#         nan        nan        nan 0.98485188 0.99365895 0.9974166
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(

# %%
result_test = grid_model.predict(X_test_meta)

# %%
grid_model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'learning_rate': 0.01,
#  'loss': 'log_loss',
#  'n_estimators': 100}

# %%
grid_model.best_score_
# Out:
# 0.955377390015451

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,f_macro,p_macro,r_macro,None])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,None])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC  F1-score  Precision    Recall  specificity
# 0          AFIB  0.950235  0.939326   0.841046  0.887473     0.953116
# 1            SB  0.921127  0.988432   0.828664  0.901524     0.882396
# 2            SR  0.829108  0.602247   0.589011  0.595556     0.889021
# 3          GSVT  0.882629  0.500000   0.924000  0.648876     0.988609
# 4     macro avg       NaN  0.758357   0.795680  0.757501          NaN
# 5     micro avg       NaN  0.791549   0.791549  0.791549          NaN
# 6  weighted avg       NaN  0.779866   0.801861  0.791549          NaN

# %%
# df_evaluation_test.to_csv("./Result/Blending_GB_pso.csv")
