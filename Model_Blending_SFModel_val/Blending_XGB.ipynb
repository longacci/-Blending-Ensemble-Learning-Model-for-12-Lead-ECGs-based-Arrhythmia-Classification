# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
df_train = pd.read_csv("../data_train_frequency_new.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)
df_train
# Out:
#       Rhythm  Rcount_lead1  RRInterval_mean_lead1  RRInterval_median_lead1  \
# 0          2          11.0             898.400000                    901.0
# 1          1           9.0            1048.750000                   1054.0
# 2          1           9.0            1058.750000                   1064.0
# 3          3          18.0             548.235294                    550.0
# 4          1           8.0            1094.285714                   1104.0
# ...      ...           ...                    ...                      ...
# 8511       1           9.0            1114.000000                   1133.0
# 8512       0          11.0             942.200000                    940.0
# 8513       2          12.0             828.727273                    832.0
# 8514       1           9.0            1040.750000                   1034.0
# 8515       1          10.0            1023.777778                   1024.0
#
#       RRInterval_std_lead1  RRInterval_range_lead1  RRInterval_skew_lead1  \
# 0                24.848340                    72.0              -0.272513
# 1                16.731333                    48.0              -0.527204
# 2                21.492731                    62.0              -0.424723
# 3                 3.208984                    10.0              -0.448220
# 4                36.385689                   102.0              -0.364315
# ...                    ...                     ...                    ...
# 8511             41.121770                   124.0              -0.956470
# 8512            323.545916                  1166.0               1.575627
# 8513              7.046481                    24.0              -0.713989
# 8514             25.533067                    80.0               0.637976
# 8515              3.583226                    10.0              -0.528579
#
#       RRInterval_kurtosis_lead1  \
# 0                     -1.338262
# 1                     -1.141916
# 2                     -1.268694
# 3                     -1.125694
# 4                     -1.177124
# ...                         ...
# 8511                  -0.432652
# 8512                   2.039130
# 8513                  -0.556833
# 8514                  -0.821729
# 8515                  -1.029763
#
#       R_peaks_amplitude_from_isoelectric_mean_lead1  PRovercount_lead1  ...  \
# 0                                        161.222201                1.0  ...
# 1                                        535.471107                1.0  ...
# 2                                        539.209477                1.0  ...
# 3                                        800.711508                1.0  ...
# 4                                        499.175352                1.0  ...
# ...                                             ...                ...  ...
# 8511                                     461.775231                1.0  ...
# 8512                                      47.162560                1.0  ...
# 8513                                     762.366987                1.0  ...
# 8514                                     393.076036                1.0  ...
# 8515                                     562.861003                1.0  ...
#
#       PRovercount_lead12  medianOfRInterSubMedianOfPInter_lead12  \
# 0               1.000000                                    -1.0
# 1               1.000000                                     9.0
# 2               0.888889                                     1.0
# 3               1.000000                                     4.0
# 4               1.000000                                   -68.0
# ...                  ...                                     ...
# 8511            0.700000                                   191.0
# 8512            0.916667                                   167.0
# 8513            1.000000                                     6.0
# 8514            1.000000                                     2.0
# 8515            1.000000                                     0.0
#
#       Tcount_lead12  Qcount_lead12  PR_intervals_mean_lead12  \
# 0              11.0           10.0                 94.444444
# 1               9.0            8.0                 86.750000
# 2               9.0            7.0                 86.285714
# 3              13.0           16.0                158.000000
# 4               8.0            6.0                200.333333
# ...             ...            ...                       ...
# 8511            9.0            8.0                223.600000
# 8512           12.0           10.0                276.222222
# 8513            3.0            1.0                164.000000
# 8514            9.0            2.0                156.000000
# 8515            9.0            7.0                129.142857
#
#       PR_intervals_var_lead12  PR_segment_mean_lead12  PR_segment_var_lead12  \
# 0                 1692.246914               -5.800000            1050.760000
# 1                 4560.937500              -34.500000            2496.750000
# 2                 1215.346939              -12.571429            1680.816327
# 3                  269.000000               84.000000             277.500000
# 4                 6909.888889               63.000000            7910.333333
# ...                       ...                     ...                    ...
# 8511              9733.440000               88.666667            9786.222222
# 8512              7992.395062              180.666667            5493.333333
# 8513                 0.000000               28.000000               0.000000
# 8514              6400.000000                5.000000            3025.000000
# 8515              1264.979592               -9.428571            2327.673469
#
#       ST_segment_mean_lead12  ST_segment_var_lead12
# 0                 128.000000              25.454545
# 1                 159.777778             386.172840
# 2                 135.333333             891.555556
# 3                 139.692308             667.597633
# 4                 119.142857            7444.408163
# ...                      ...                    ...
# 8511              122.000000             294.000000
# 8512              187.666667            3377.888889
# 8513              182.666667             118.222222
# 8514              140.444444             694.913580
# 8515              158.444444             333.135802
#
# [8516 rows x 213 columns]

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
scale = MinMaxScaler()
x_train = scale.fit_transform(x_train)

# %%
df_test = pd.read_csv("../data_test_frequency_new.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)
df_test
# Out:
#       Rhythm  Rcount_lead1  RRInterval_mean_lead1  RRInterval_median_lead1  \
# 0          3          21.0             453.100000                    443.0
# 1          3          18.0             536.000000                    536.0
# 2          0          17.0             545.000000                    522.0
# 3          3          29.0             339.642857                    339.0
# 4          0          16.0             580.133333                    584.0
# ...      ...           ...                    ...                      ...
# 2125       1          10.0            1011.777778                   1004.0
# 2126       0          17.0             555.250000                    560.0
# 2127       1          12.0             793.818182                    602.0
# 2128       1          10.0            1027.555556                   1034.0
# 2129       3          30.0             323.586207                    324.0
#
#       RRInterval_std_lead1  RRInterval_range_lead1  RRInterval_skew_lead1  \
# 0               113.667014                   384.0               0.408072
# 1                 7.881475                    22.0              -0.103811
# 2               106.402538                   392.0               0.494665
# 3                 7.579174                    22.0               0.016127
# 4                79.694305                   258.0              -0.199141
# ...                    ...                     ...                    ...
# 2125             42.493863                   138.0              -0.076001
# 2126            103.667437                   336.0               0.241246
# 2127            305.346842                   782.0               0.161022
# 2128             13.259052                    38.0              -0.463020
# 2129              1.608538                     4.0               0.391074
#
#       RRInterval_kurtosis_lead1  \
# 0                     -1.010019
# 1                     -1.460399
# 2                     -0.589332
# 3                     -1.517037
# 4                     -1.159748
# ...                         ...
# 2125                  -1.015525
# 2126                  -0.952323
# 2127                  -1.790316
# 2128                  -1.266572
# 2129                  -1.350765
#
#       R_peaks_amplitude_from_isoelectric_mean_lead1  PRovercount_lead1  ...  \
# 0                                         93.794110           1.000000  ...
# 1                                        435.367400           1.000000  ...
# 2                                        437.577682           1.000000  ...
# 3                                        962.198974           0.655172  ...
# 4                                        270.426409           1.000000  ...
# ...                                             ...                ...  ...
# 2125                                     102.541896           1.000000  ...
# 2126                                     154.002823           1.000000  ...
# 2127                                     345.645608           1.000000  ...
# 2128                                     235.897545           1.000000  ...
# 2129                                     288.150323           1.000000  ...
#
#       PRovercount_lead12  medianOfRInterSubMedianOfPInter_lead12  \
# 0               0.636364                                    60.0
# 1               1.000000                                     0.0
# 2               0.941176                                     7.0
# 3               0.344828                                    17.0
# 4               0.687500                                   -16.0
# ...                  ...                                     ...
# 2125            1.000000                                    -3.0
# 2126            0.937500                                    -6.0
# 2127            1.000000                                   -17.0
# 2128            1.000000                                     2.0
# 2129            1.000000                                     0.0
#
#       Tcount_lead12  Qcount_lead12  PR_intervals_mean_lead12  \
# 0               2.0           18.0                 80.666667
# 1              17.0           13.0                 67.384615
# 2               7.0            5.0                 88.666667
# 3               1.0            3.0                  0.044242
# 4              12.0           15.0                154.727273
# ...             ...            ...                       ...
# 2125            9.0            9.0                119.111111
# 2126            8.0            7.0                 79.428571
# 2127            9.0            8.0                 60.285714
# 2128            9.0            9.0                185.500000
# 2129            5.0           29.0                 69.448276
#
#       PR_intervals_var_lead12  PR_segment_mean_lead12  PR_segment_var_lead12  \
# 0                 2561.777778               -2.181818            1277.421488
# 1                 1330.698225              -44.923077            1074.224852
# 2                 3512.888889              -40.500000             140.750000
# 3                    0.044242                0.043021               0.043021
# 4                 3873.652893               76.909091            1427.173554
# ...                       ...                     ...                    ...
# 2125              5338.765432               -4.666667            3948.444444
# 2126              2460.244898               -4.571429             891.102041
# 2127               659.918367               -4.250000            5788.437500
# 2128              1227.750000               60.000000            3651.555556
# 2129               967.143876              -29.586207             989.346017
#
#       ST_segment_mean_lead12  ST_segment_var_lead12
# 0                  14.000000            1444.000000
# 1                  71.764706            1131.709343
# 2                  44.857143            4076.408163
# 3                 -14.000000               0.000000
# 4                  76.333333             351.222222
# ...                      ...                    ...
# 2125              268.888889            2381.432099
# 2126               46.250000            2534.437500
# 2127              211.777778             582.617284
# 2128               -9.333333            6775.555556
# 2129              -20.000000               0.000000
#
# [2130 rows x 213 columns]

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
x_test = scale.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train , test_size=0.3, shuffle=True, stratify=y_train, random_state=10)
print(f"Train: {x_train.shape}")
print(f"Vallidation: {x_val.shape}")
# Out:
# Train: (5961, 212)
# Vallidation: (2555, 212)

# %%
rf_clf = RandomForestClassifier(criterion= 'entropy', max_depth= 15, max_features= 'sqrt', n_estimators= 40)
ab_clf = AdaBoostClassifier(algorithm= 'SAMME.R', learning_rate= 0.1, n_estimators= 61)
knn_clf = KNeighborsClassifier(algorithm= 'auto', n_neighbors= 8, p= 1, weights= 'uniform')
svc_clf = SVC(C= 15, gamma= 'scale', kernel= 'rbf', probability= True)
xgb_clf = XGBClassifier(gamma= 0,learning_rate= 0.05,max_depth= 5,min_child_weight= 1,n_estimators= 950)
lr_clf = LogisticRegression(C= 0.14, max_iter= 30, multi_class= 'auto', n_jobs= -1, penalty= 'l2', solver= 'sag', tol= 0.015)
dt_clf = DecisionTreeClassifier(criterion= 'entropy',max_depth= 6,max_features= 'sqrt',splitter= 'best')

# %%
# Huấn luyện các mô hình con
rf_clf.fit(x_train,y_train)
ab_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
svc_clf.fit(x_train, y_train)
xgb_clf.fit(x_train, y_train)
dt_clf.fit(x_train,y_train)
lr_clf.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# LogisticRegression(C=0.14, max_iter=30, n_jobs=-1, solver='sag', tol=0.015)

# %%
# Dự đoán trên tập huấn luyện để tạo đặc trưng mới cho mô hình blending
X_train_meta = np.column_stack((
    rf_clf.predict_proba(x_val),
    xgb_clf.predict_proba(x_val),
    svc_clf.predict_proba(x_val),
    knn_clf.predict_proba(x_val),
    ab_clf.predict_proba(x_val),
    dt_clf.predict_proba(x_val),
    lr_clf.predict_proba(x_val)
    
))
# Dự đoán trên tập kiểm tra để tạo đặc trưng mới cho mô hình blending
X_test_meta = np.column_stack((
    rf_clf.predict_proba(x_test),
    xgb_clf.predict_proba(x_test),
    svc_clf.predict_proba(x_test),
    knn_clf.predict_proba(x_test),
    ab_clf.predict_proba(x_test),
    dt_clf.predict_proba(x_test),
    lr_clf.predict_proba(x_test),
    
))

# %%
print(f"X_train_meta:{X_train_meta.shape}")
print(f"X_test_meta:{X_test_meta.shape}")
# Out:
# X_train_meta:(2555, 28)
# X_test_meta:(2130, 28)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
model = XGBClassifier()
params = {
    'n_estimators': [10,50,100,500],
    'learning_rate': [0.01,0.1,0.2,0.4],
    'max_depth': [3,4,5],
    'min_child_weight':[1],
    'gamma':[0.1,0.2],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X_train_meta,y_val)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.973, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.953) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.975, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.971, test=0.954) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.970, test=0.952) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.975, test=0.954) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.978, test=0.958) total time=   0.9s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.978, test=0.946) total time=   0.9s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.984, test=0.953) total time=   1.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.978, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.946) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.949) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.979, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.976, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.981, test=0.955) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.977, test=0.950) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.954) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.989, test=0.961) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.988, test=0.947) total time=   1.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.991, test=0.955) total time=   1.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.978, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.949) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.952) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.982, test=0.954) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.980, test=0.951) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.987, test=0.955) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.959) total time=   1.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.997, test=0.950) total time=   1.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.953) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.954) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.960) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.946) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.993, test=0.952) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.959) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.950) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.954) total time=   0.5s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.978, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.983, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.992, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.959) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.951) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.960) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.951) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.958) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.954) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.952) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.959) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.948) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.954) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.976, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.991, test=0.946) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.993, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.947) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.953) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.958) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.947) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.953) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.983, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.958) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.951) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.953) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.953) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.958) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.950) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.952) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.975, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.947) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.954) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.991, test=0.952) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.960) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.948) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.954) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.994, test=0.964) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.960) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.950) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.954) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.973, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.953) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.975, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.971, test=0.954) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.970, test=0.952) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.975, test=0.955) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.978, test=0.958) total time=   0.9s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.978, test=0.946) total time=   0.9s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.984, test=0.953) total time=   1.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.946) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.951) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.977, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.975, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.980, test=0.957) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.976, test=0.947) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.983, test=0.954) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.988, test=0.961) total time=   1.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.989, test=0.948) total time=   1.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.991, test=0.955) total time=   1.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.978, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.949) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.959) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.953) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.982, test=0.954) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.979, test=0.952) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.987, test=0.957) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.995, test=0.961) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.952) total time=   1.5s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.995, test=0.953) total time=   1.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.954) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.978, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.989, test=0.960) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.946) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.952) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.994, test=0.960) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.994, test=0.950) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.951) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.977, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.983, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.991, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.959) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.947) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.951) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.997, test=0.958) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.947) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.951) total time=   0.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.958) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.995, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.952) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.995, test=0.952) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.959) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.952) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.951) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.959) total time=   0.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.951) total time=   0.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.953) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.953) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.977, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.992, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.994, test=0.951) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.959) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.951) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.959) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.948) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.996, test=0.951) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.998, test=0.951) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.958) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.945) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.953) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.958) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.945) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.953) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.985, test=0.955) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.951) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.954) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.957) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.960) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.957) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.960) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.950) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.957) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.960) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.975, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.980, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.946) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.998, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.995, test=0.957) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.997, test=0.946) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.953) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.995, test=0.957) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.997, test=0.946) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.953) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.958) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.991, test=0.958) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.998, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.944) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.998, test=0.959) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.944) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=4, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.955) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.994, test=0.959) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.994, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.961) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.952) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.955) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=0.999, test=0.961) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.952) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=500;, score=(train=1.000, test=0.955) total time=   0.3s

# %%
result_test = grid_model.predict(X_test_meta)

# %%
grid_model.best_params_
# Out:
# {'gamma': 0.1,
#  'learning_rate': 0.4,
#  'max_depth': 5,
#  'min_child_weight': 1,
#  'n_estimators': 10}

# %%
grid_model.best_score_
# Out:
# 0.9561640636349761

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,f_macro,p_macro,r_macro,None])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,None])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC  F1-score  Precision    Recall  specificity
# 0          AFIB  0.966197  0.912360   0.924829  0.918552     0.980415
# 1            SB  0.991549  0.989717   0.987179  0.988447     0.992604
# 2            SR  0.983568  0.959551   0.961712  0.960630     0.989911
# 3          GSVT  0.970423  0.937229   0.927195  0.932185     0.979616
# 4     macro avg       NaN  0.949953   0.950229  0.949714          NaN
# 5     micro avg       NaN  0.955869   0.955869  0.955869          NaN
# 6  weighted avg       NaN  0.955830   0.955822  0.955869          NaN

# %%
# df_evaluation_test.to_csv("./Result/Blending_XGB_6_0_2.csv")
