# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
df_train = pd.read_csv("./data_train_frequency_merge.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)
df_train
# Out:
#       Rhythm  Rcount_lead1  RRInterval_mean_lead1  RRInterval_median_lead1  \
# 0          1           8.0            1080.857143                   1086.0
# 1          3          18.0             535.764706                    536.0
# 2          1           7.0            1344.333333                   1581.0
# 3          3          17.0             561.500000                    562.0
# 4          2          16.0             612.400000                    612.0
# ...      ...           ...                    ...                      ...
# 8511       3          17.0             559.750000                    561.0
# 8512       1           8.0            1211.714286                   1212.0
# 8513       2          12.0             789.272727                    792.0
# 8514       0          18.0             514.823529                    490.0
# 8515       1           9.0            1133.500000                   1135.0
#
#       RRInterval_std_lead1  RRInterval_range_lead1  RRInterval_skew_lead1  \
# 0                21.879074                    66.0              -0.622052
# 1                 1.351662                     4.0               0.146383
# 2               402.603886                   974.0              -0.717501
# 3                 4.609772                    16.0              -0.367506
# 4                 4.963869                    14.0               0.163258
# ...                    ...                     ...                    ...
# 8511              3.929058                    16.0              -0.666167
# 8512             20.126133                    60.0               0.117312
# 8513             24.764678                    96.0              -1.129683
# 8514            115.746292                   402.0               0.832975
# 8515             13.444330                    46.0              -0.654613
#
#       RRInterval_kurtosis_lead1  \
# 0                     -0.821453
# 1                     -0.825069
# 2                     -1.392992
# 3                     -0.701176
# 4                     -1.136195
# ...                         ...
# 8511                   0.137849
# 8512                  -1.249265
# 8513                   0.997705
# 8514                  -0.335017
# 8515                  -0.225903
#
#       R_peaks_amplitude_from_isoelectric_mean_lead1  PRovercount_lead1  ...  \
# 0                                        694.163664           1.000000  ...
# 1                                        149.028032           1.000000  ...
# 2                                        302.224787           0.857143  ...
# 3                                        804.877251           1.000000  ...
# 4                                        451.559324           1.000000  ...
# ...                                             ...                ...  ...
# 8511                                     630.195529           1.000000  ...
# 8512                                     441.849082           1.000000  ...
# 8513                                     278.529342           1.000000  ...
# 8514                                      92.402139           1.000000  ...
# 8515                                     592.118309           1.000000  ...
#
#       AtrialRate  QRSDuration  QTInterval  QTCorrected  RAxis  TAxis  \
# 0             56          106         436          420     50      7
# 1            112           70         354          483     56     45
# 2              0           92         426          368     51     70
# 3            107           88         338          451    -12     74
# 4             98           78         352          449     54     33
# ...          ...          ...         ...          ...    ...    ...
# 8511         107           80         348          464     22    135
# 8512          50          110         402          366     55     56
# 8513          76           76         374          420     42     -4
# 8514         129           72         274          415     86    -81
# 8515          53           86         470          441     26     45
#
#       QRSCount  QOnset  QOffset  TOffset
# 0           10     219      272      437
# 1           18     229      264      406
# 2            7     216      262      429
# 3           18     216      260      385
# 4           16     218      257      394
# ...        ...     ...      ...      ...
# 8511        17     225      265      399
# 8512         8     216      271      417
# 8513        12     219      257      406
# 8514        23     218      254      355
# 8515         9     220      263      455
#
# [8516 rows x 226 columns]

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
scale = MinMaxScaler()
x_train = scale.fit_transform(x_train)

# %%
df_test = pd.read_csv("./data_test_frequency_merge.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)
df_test
# Out:
#       Rhythm  Rcount_lead1  RRInterval_mean_lead1  RRInterval_median_lead1  \
# 0          2          12.0             806.545455                    742.0
# 1          3          17.0             570.000000                    570.0
# 2          1           9.0            1159.500000                   1156.0
# 3          3          21.0             460.900000                    370.0
# 4          3          18.0             555.882353                    556.0
# ...      ...           ...                    ...                      ...
# 2125       1           9.0            1023.250000                   1023.0
# 2126       2          14.0             652.461538                    646.0
# 2127       1           9.0            1124.000000                   1135.0
# 2128       1           8.0            1144.000000                   1148.0
# 2129       2          12.0             804.363636                    800.0
#
#       RRInterval_std_lead1  RRInterval_range_lead1  RRInterval_skew_lead1  \
# 0               139.662166                   498.0               1.930425
# 1                 3.316625                    12.0               0.246691
# 2                30.995967                    80.0               0.143027
# 3               197.475543                   740.0               2.060318
# 4                 8.525963                    28.0              -0.187149
# ...                    ...                     ...                    ...
# 2125              7.996093                    24.0              -0.157885
# 2126             31.183367                   104.0               0.254349
# 2127             33.075671                    98.0              -0.221530
# 2128             20.674346                    66.0              -0.481105
# 2129             20.392836                    68.0               0.381454
#
#       RRInterval_kurtosis_lead1  \
# 0                      2.666314
# 1                     -0.553719
# 2                     -1.646515
# 3                      3.244488
# 4                     -1.101203
# ...                         ...
# 2125                  -1.293608
# 2126                  -0.953411
# 2127                  -1.372342
# 2128                  -0.769574
# 2129                  -0.685607
#
#       R_peaks_amplitude_from_isoelectric_mean_lead1  PRovercount_lead1  ...  \
# 0                                         72.781980           1.000000  ...
# 1                                        196.378284           1.000000  ...
# 2                                        131.265115           1.000000  ...
# 3                                         92.225535           0.857143  ...
# 4                                        187.851047           1.000000  ...
# ...                                             ...                ...  ...
# 2125                                     872.646176           1.000000  ...
# 2126                                     344.958851           1.000000  ...
# 2127                                     467.241572           1.000000  ...
# 2128                                     123.061280           1.000000  ...
# 2129                                     244.418751           1.000000  ...
#
#       AtrialRate  QRSDuration  QTInterval  QTCorrected  RAxis  TAxis  \
# 0             73           80         370          407     88     58
# 1            105           98         368          486     75     52
# 2             52          158         492          457    203     -2
# 3            163          138         270          444     97    262
# 4            108           76         346          463     18     50
# ...          ...          ...         ...          ...    ...    ...
# 2125          59          102         464          459     25     15
# 2126          92           88         356          440     65     48
# 2127          53           84         418          392     24     22
# 2128          52          100         422          392     83     70
# 2129          75           74         336          375     77     47
#
#       QRSCount  QOnset  QOffset  TOffset
# 0           12     220      260      405
# 1           17     214      263      398
# 2            9     226      305      472
# 3           27     207      276      342
# 4           18     216      254      389
# ...        ...     ...      ...      ...
# 2125        10     215      266      447
# 2126        15     222      266      400
# 2127         9     220      262      429
# 2128         8     215      265      426
# 2129        12     220      257      388
#
# [2130 rows x 226 columns]

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
x_test = scale.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train , test_size=0.5, shuffle=True, stratify=y_train, random_state=119)
print(f"Train: {x_train.shape}")
print(f"Vallidation: {x_val.shape}")
# Out:
# Train: (4258, 225)
# Vallidation: (4258, 225)

# %%
rf_clf = RandomForestClassifier(criterion= 'log_loss', max_depth= 5, max_features= 'sqrt', n_estimators= 1000)
ab_clf = AdaBoostClassifier(algorithm= 'SAMME.R', learning_rate= 0.1, n_estimators= 50)
knn_clf = KNeighborsClassifier(algorithm= 'auto', n_neighbors= 5, p= 1, weights= 'uniform')
# svc_clf = SVC(C= 100, gamma= 'scale', kernel= 'rbf', probability= True)
xgb_clf = XGBClassifier(gamma= 0,learning_rate= 0.1,max_depth= 5,min_child_weight= 1,n_estimators= 1000)
dt_clf = DecisionTreeClassifier(criterion= 'entropy',max_depth= 5,max_features= 'sqrt',splitter= 'best')

# %%
# Huấn luyện các mô hình con
rf_clf.fit(x_train,y_train)
ab_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
# svc_clf.fit(x_train, y_train)
xgb_clf.fit(x_train, y_train)
dt_clf.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt')

# %%
# Dự đoán trên tập huấn luyện để tạo đặc trưng mới cho mô hình blending
X_train_meta = np.column_stack((
    rf_clf.predict_proba(x_val),
    ab_clf.predict_proba(x_val),
    knn_clf.predict_proba(x_val),
    # svc_clf.predict_proba(x_val),
    xgb_clf.predict_proba(x_val),
    dt_clf.predict_proba(x_val)
))
# Dự đoán trên tập kiểm tra để tạo đặc trưng mới cho mô hình blending
X_test_meta = np.column_stack((
    rf_clf.predict_proba(x_test),
    ab_clf.predict_proba(x_test),
    knn_clf.predict_proba(x_test),
    # svc_clf.predict_proba(x_test),
    xgb_clf.predict_proba(x_test),
    dt_clf.predict_proba(x_test)
))

# %%
print(f"X_train_meta:{X_train_meta.shape}")
print(f"X_test_meta:{X_test_meta.shape}")
# Out:
# X_train_meta:(4258, 20)
# X_test_meta:(2130, 20)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
model = SVC()
params = {
    'kernel': ['rbf', 'sigmoid', 'poly', 'linear'],
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': ['scale', 'auto'],
    'probability': [True]
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X_train_meta,y_val)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [CV 1/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.959, test=0.952) total time=   0.6s
# [CV 2/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.959, test=0.951) total time=   0.6s
# [CV 3/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.953, test=0.967) total time=   0.6s
# [CV 1/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.958, test=0.951) total time=   0.6s
# [CV 2/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.958, test=0.951) total time=   0.6s
# [CV 3/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.951, test=0.966) total time=   0.6s
# [CV 1/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.961, test=0.955) total time=   0.1s
# [CV 2/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.959, test=0.951) total time=   0.1s
# [CV 3/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.955, test=0.967) total time=   0.2s
# [CV 1/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.963, test=0.957) total time=   0.1s
# [CV 2/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.963, test=0.956) total time=   0.1s
# [CV 3/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.958, test=0.968) total time=   0.1s
# [CV 1/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.957, test=0.950) total time=   1.4s
# [CV 2/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.957, test=0.950) total time=   1.5s
# [CV 3/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.950, test=0.965) total time=   1.6s
# [CV 1/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.952, test=0.948) total time=   1.4s
# [CV 2/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.953, test=0.948) total time=   1.4s
# [CV 3/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.948, test=0.958) total time=   1.4s
# [CV 1/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.365, test=0.365) total time=   1.1s
# [CV 2/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.366, test=0.365) total time=   1.1s
# [CV 3/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.365, test=0.366) total time=   1.1s
# [CV 1/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.963, test=0.957) total time=   0.1s
# [CV 2/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.963, test=0.956) total time=   0.1s
# [CV 3/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.958, test=0.968) total time=   0.1s
# [CV 1/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.965, test=0.958) total time=   0.1s
# [CV 2/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.963, test=0.961) total time=   0.2s
# [CV 3/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.961, test=0.968) total time=   0.2s
# [CV 1/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.964, test=0.958) total time=   0.1s
# [CV 2/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.963, test=0.963) total time=   0.1s
# [CV 3/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.960, test=0.967) total time=   0.1s
# [CV 1/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.965, test=0.959) total time=   0.0s
# [CV 2/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.963, test=0.960) total time=   0.0s
# [CV 3/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.962, test=0.968) total time=   0.0s
# [CV 1/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.964, test=0.961) total time=   0.0s
# [CV 2/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.963, test=0.962) total time=   0.0s
# [CV 3/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.962, test=0.967) total time=   0.0s
# [CV 1/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.963, test=0.957) total time=   0.2s
# [CV 2/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.963, test=0.954) total time=   0.3s
# [CV 3/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.958, test=0.968) total time=   0.3s
# [CV 1/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.960, test=0.954) total time=   0.2s
# [CV 2/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.960, test=0.953) total time=   0.2s
# [CV 3/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.955, test=0.967) total time=   0.2s
# [CV 1/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.471, test=0.476) total time=   1.1s
# [CV 2/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.471, test=0.459) total time=   1.1s
# [CV 3/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.464, test=0.472) total time=   1.1s
# [CV 1/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.964, test=0.961) total time=   0.0s
# [CV 2/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.963, test=0.962) total time=   0.0s
# [CV 3/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.962, test=0.967) total time=   0.0s
# [CV 1/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.967, test=0.960) total time=   0.1s
# [CV 2/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.964, test=0.961) total time=   0.1s
# [CV 3/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.964, test=0.969) total time=   0.1s
# [CV 1/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.955, test=0.952) total time=   0.0s
# [CV 2/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.958, test=0.954) total time=   0.0s
# [CV 3/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.954, test=0.959) total time=   0.0s
# [CV 1/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.967, test=0.958) total time=   0.0s
# [CV 2/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.965, test=0.961) total time=   0.0s
# [CV 3/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.965, test=0.968) total time=   0.0s
# [CV 1/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.965, test=0.961) total time=   0.0s
# [CV 2/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.964, test=0.963) total time=   0.0s
# [CV 3/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.962, test=0.968) total time=   0.0s
# [CV 1/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.964, test=0.961) total time=   0.1s
# [CV 2/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.964, test=0.961) total time=   0.1s
# [CV 3/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.961, test=0.968) total time=   0.1s
# [CV 1/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.964, test=0.961) total time=   0.0s
# [CV 2/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.963, test=0.961) total time=   0.0s
# [CV 3/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.961, test=0.968) total time=   0.0s
# [CV 1/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.956, test=0.949) total time=   0.4s
# [CV 2/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.955, test=0.944) total time=   0.4s
# [CV 3/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.948, test=0.965) total time=   0.4s
# [CV 1/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.965, test=0.961) total time=   0.0s
# [CV 2/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.964, test=0.963) total time=   0.0s
# [CV 3/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.962, test=0.968) total time=   0.0s
# [CV 1/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.970, test=0.961) total time=   0.1s
# [CV 2/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.968, test=0.962) total time=   0.1s
# [CV 3/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.970, test=0.968) total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.957, test=0.951) total time=   0.0s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.953, test=0.948) total time=   0.0s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.950, test=0.958) total time=   0.0s
# [CV 1/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.970, test=0.961) total time=   0.1s
# [CV 2/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.969, test=0.961) total time=   0.1s
# [CV 3/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.971, test=0.968) total time=   0.1s
# [CV 1/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.965, test=0.960) total time=   0.1s
# [CV 2/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.964, test=0.963) total time=   0.1s
# [CV 3/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.962, test=0.967) total time=   0.1s
# [CV 1/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.965, test=0.959) total time=   0.0s
# [CV 2/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.963, test=0.963) total time=   0.0s
# [CV 3/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.962, test=0.968) total time=   0.1s
# [CV 1/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.965, test=0.961) total time=   0.0s
# [CV 2/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.964, test=0.962) total time=   0.0s
# [CV 3/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.963, test=0.968) total time=   0.0s
# [CV 1/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.963, test=0.957) total time=   0.1s
# [CV 2/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.961, test=0.955) total time=   0.1s
# [CV 3/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.958, test=0.967) total time=   0.1s
# [CV 1/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.965, test=0.960) total time=   0.1s
# [CV 2/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.964, test=0.963) total time=   0.1s
# [CV 3/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.962, test=0.967) total time=   0.1s
# [CV 1/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.973, test=0.962) total time=   0.2s
# [CV 2/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.972, test=0.961) total time=   0.2s
# [CV 3/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.974, test=0.968) total time=   0.2s
# [CV 1/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.952, test=0.939) total time=   0.0s
# [CV 2/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.940, test=0.935) total time=   0.0s
# [CV 3/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.940, test=0.944) total time=   0.0s
# [CV 1/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.975, test=0.958) total time=   0.2s
# [CV 2/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.971, test=0.955) total time=   0.2s
# [CV 3/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.974, test=0.966) total time=   0.2s
# [CV 1/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.965, test=0.959) total time=   0.3s
# [CV 2/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.965, test=0.961) total time=   0.3s
# [CV 3/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.963, test=0.967) total time=   0.3s
# [CV 1/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.968, test=0.960) total time=   0.1s
# [CV 2/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.967, test=0.961) total time=   0.1s
# [CV 3/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.967, test=0.967) total time=   0.1s
# [CV 1/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.964, test=0.959) total time=   0.1s
# [CV 2/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.963, test=0.958) total time=   0.1s
# [CV 3/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.960, test=0.964) total time=   0.1s
# [CV 1/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.965, test=0.958) total time=   0.0s
# [CV 2/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.963, test=0.961) total time=   0.0s
# [CV 3/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.962, test=0.968) total time=   0.0s
# [CV 1/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.965, test=0.959) total time=   0.3s
# [CV 2/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.965, test=0.961) total time=   0.3s
# [CV 3/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.963, test=0.967) total time=   0.3s

# %%
result_test = grid_model.predict(X_test_meta)

# %%
grid_model.best_params_
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf', 'probability': True}

# %%
grid_model.best_score_
# Out:
# 0.963833387924446

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,f_macro,p_macro,r_macro,None])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,None])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC  F1-score  Precision    Recall  specificity
# 0          AFIB  0.969484  0.923596   0.929864  0.926719     0.981602
# 1            SB  0.995305  0.996144   0.991049  0.993590     0.994822
# 2            SR  0.987793  0.973034   0.968680  0.970852     0.991691
# 3          GSVT  0.971362  0.930736   0.936819  0.933768     0.982614
# 4     macro avg       NaN  0.956232   0.956603  0.955877          NaN
# 5     micro avg       NaN  0.961972   0.961972  0.961972          NaN
# 6  weighted avg       NaN  0.961893   0.961830  0.961972          NaN

# %%
df_evaluation_test.to_csv("../Result/Blending_SVM_125ft.csv")
